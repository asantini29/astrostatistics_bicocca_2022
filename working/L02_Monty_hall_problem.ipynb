# %% [markdown]
# # Monty Hall Problem

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [8, 8]

# %config InlineBackend.figure_format='retina'

# %%
doors = [0, 1, 1] # 0 is the car, 1 is the goat
N = 100000
cons = np.empty(N) #conservative player
switch = np.empty(N) #switcher player
new = np.empty(N) #newcomer player

# %%
for i in range(N):    
    choice = np.random.choice(doors)
    cons[i] = choice
    switch[i] = 1 - choice
    new[i] = np.random.choice([0,1])

# %%
fig, axs = plt.subplots(1, 3)
axs[0].hist(cons)
axs[0].set_title('Conservative')
axs[1].hist(switch)
axs[1].set_title('Switcher')
axs[2].hist(new)
axs[2].set_title('Newcomer')

for ax in axs.flat:
    ax.set(xlabel='result', ylabel='counts')

for ax in axs.flat:
    ax.label_outer()

# %%
P_cons = len(cons[cons == 0]) /  N 
P_switch = len(switch[switch == 0]) /  N 
P_new = len(new[new == 0]) /  N 
print("the probability for the conservative is: ", P_cons)
print("the probability for the switcher is: ", P_switch)
print("the probability for the newcomer is: ", P_new)
# Out:
# the probability for the conservative is:  0.33319
# the probability for the switcher is:  0.66681
# the probability for the newcomer is:  0.49966

# %% [markdown]
# ## with 100 doors and 99 goats

# %%
doors = np.ones(100)
doors[0] = 0 
N = 50000
cons = np.empty(N)
switch = np.empty(N)
new = np.empty(N)

# %%
for i in range(N):    
    choice = np.random.choice(doors)
    cons[i] = choice
    switch[i] = 1 - choice
    new[i] = np.random.choice([0,1])

# %%
fig, axs = plt.subplots(1, 3)
axs[0].hist(cons)
axs[0].set_title('Conservative')
axs[1].hist(switch)
axs[1].set_title('Switcher')
axs[2].hist(new)
axs[2].set_title('Newcomer')

for ax in axs.flat:
    ax.set(xlabel='result', ylabel='counts')

for ax in axs.flat:
    ax.label_outer()

# %%
P_cons = len(cons[cons == 0]) /  N 
P_switch = len(switch[switch == 0]) /  N 
P_new = len(new[new == 0]) /  N 
print("the probability for the conservative is: ", P_cons)
print("the probability for the switcher is: ", P_switch)
print("the probability for the newcomer is: ", P_new)
# Out:
# the probability for the conservative is:  0.01034
# the probability for the switcher is:  0.98966
# the probability for the newcomer is:  0.50188
